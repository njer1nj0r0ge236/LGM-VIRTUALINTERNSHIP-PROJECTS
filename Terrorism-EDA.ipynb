# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS- TERRORISM DATASET

# %% [markdown]
# ### Libraries Importation

# %%
# Data manipulation and analysis
import pandas as pd                  

# Numerical computing
import numpy as np 

# Data visualization
import matplotlib.pyplot as plt      

# Enhanced data visualization
import seaborn as sns

# %% [markdown]
# ### Data loading

# %%
df_terrosism = pd.read_csv(r"C:\Users\USER\Documents\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10508\3539419839.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_terrosism = pd.read_csv(r"C:\Users\USER\Documents\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')

# %% [markdown]
# ### EXPLORING THE DATASET

# %%
# The first 5 rows
df_terrosism.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# The last 5 rows
df_terrosism.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
# Find the number of rows and columns,datatypes for every column, and the memory size for the dataset 
df_terrosism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# Find the statistical summary of the dataset. Understand the distribution of data and identify any missing values and outliers
df_terrosism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# Find the number of columns and rows
df_terrosism.shape
# Out:
# (181691, 135)

# %%
# Fing missing values
df_terrosism.isna()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %%
df_terrosism.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df_terrosism.isnull().any()
# Out:
# eventid       False
# iyear         False
# imonth        False
# iday          False
# approxdate     True
#               ...
# INT_LOG       False
# INT_IDEO      False
# INT_MISC      False
# INT_ANY       False
# related        True
# Length: 135, dtype: bool

# %%
df_terrosism.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ## Attacks by country

# %%
# Group data by country and count the number of attacks by country.

attacks_by_country = df_terrosism.groupby('country_txt').agg({'iyear':'count'}).reset_index()

# %%
# Find country with highest number of attacks

country_most_attacks = attacks_by_country.loc[attacks_by_country['iyear'].idxmax()]
print(country_most_attacks)
# Out:
# country_txt     Iraq
# iyear          24636
# Name: 84, dtype: object

# %%
# Find the top 15 countries and the number of attacks

top_15_countries = df_terrosism.country_txt.value_counts()[:15]
print(top_15_countries)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: country_txt, dtype: int64

# %%
# Sort number of attacks in descending order

attacks_by_country.sort_values(by = 'iyear', ascending = False)
# Out:
#              country_txt  iyear
# 84                  Iraq  24636
# 134             Pakistan  14368
# 0            Afghanistan  12731
# 80                 India  11960
# 35              Colombia   8306
# ..                   ...    ...
# 5    Antigua and Barbuda      1
# 126         New Hebrides      1
# 169            St. Lucia      1
# 163        South Vietnam      1
# 131          North Korea      1
#
# [205 rows x 2 columns]

# %%
# Plot A bar for the top 15 countries and the number of attacks

plt.subplots(figsize=(16,6))
plt.bar(top_15_countries.index,top_15_countries.values)
plt.title('Top 15 Countries ')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
# Create a pivot table of the number of terrorist attacks in each country

df_terrosism_pivot = df_terrosism.pivot_table(index='country_txt', values='iyear',aggfunc='count')

# %%
# Plot a heatmap for the pivot table

sns.heatmap(df_terrosism_pivot, cmap='Blues')
# Out:
# <AxesSubplot: ylabel='country_txt'>

# %%
# Bar chart for the number of attacks by country

plt.bar(attacks_by_country.index, attacks_by_country)
plt.xlabel('country')
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 23 in 3
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X45sdW50aXRsZWQ%3D?line=0'>1</a> # Bar chart for the number of attacks by country
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X45sdW50aXRsZWQ%3D?line=2'>3</a> plt.bar(attacks_by_country.index, attacks_by_country)
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X45sdW50aXRsZWQ%3D?line=3'>4</a> plt.xlabel('country')
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X45sdW50aXRsZWQ%3D?line=4'>5</a> plt.ylabel('Number of attacks')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2367, in bar(x, height, width, bottom, align, data, **kwargs)
# ...

# %% [markdown]
# ## Attacks per city

# %%
# Group by city and count the number of cities per attack

city_attacks = df_terrosism.groupby('city').size()

# %%
# Sort the data in descending order

city_attacks = city_attacks.sort_values(ascending=False)

# %%
# Pie chart for number of attacks per city

plt.pie(city_attacks.head(10),
        labels = city_attacks.head(10).index)
plt.title('Top 10 cities with most attacks')
plt.show()

# %% [markdown]
# ## Attacks per region

# %%
# Group per region and count the number of attacks

region_attacks = df_terrosism.groupby('region_txt').size()

# %%
# Region latitudes and longitudes
longitude = df_terrosism.columns('longitude')
latitude = df_terrosism.columns('latitude')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 30 in 2
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X54sdW50aXRsZWQ%3D?line=0'>1</a> # Region latitudes and longitudes
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X54sdW50aXRsZWQ%3D?line=1'>2</a> longitude = df_terrosism.columns('longitude')
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X54sdW50aXRsZWQ%3D?line=2'>3</a> latitude = df_terrosism.columns('latitude')
#
# TypeError: 'Index' object is not callable

# %%
# Scatter plot chart for number of attacks per region

plt.scatter(df_terrosism.longitude.values(),
            df_terrosism.latitude.values(),
            s=region_attacks,
            alpha=0.5)
plt.title('Number of attacks per region')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 31 in 3
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X55sdW50aXRsZWQ%3D?line=0'>1</a> # Scatter plot chart for number of attacks per region
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X55sdW50aXRsZWQ%3D?line=2'>3</a> plt.scatter(df_terrosism.longitude.values(),
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X55sdW50aXRsZWQ%3D?line=3'>4</a>             df_terrosism.latitude.values(),
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X55sdW50aXRsZWQ%3D?line=4'>5</a>             s=region_attacks,
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X55sdW50aXRsZWQ%3D?line=5'>6</a>             alpha=0.5)
# ...

# %% [markdown]
# ## Attacks per year

# %%
# Convert the date column to a datetime object

df_terrosism['iyear'] = pd.to_datetime(df_terrosism['iyear'],format='%Y')

# %%
# Group by year and count number of attacks per year

year_attacks = df_terrosism.groupby('iyear').size()

# %%
# Histogram for the number of attacks per year

plt.hist(year_attacks,
         bins=range(1970,2018,1),
         edgecolor='red')
plt.title('Histogram for Number of attacks per year')
plt.xlabel('Year')
plt.ylabel('Number of attacks')
plt.show()

# %% [markdown]
# ## Attacks per month

# %%
# Convert date column to datetime object

df_terrosism['date'] = pd.to_datetime(df_terrosism['iyear'].astype(str) + df_terrosism['imonth'].astype(str) + df_terrosism['iday'].astype(str) , format='%Y,%m,%day')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\tslibs\strptime.pyx:109, in pandas._libs.tslibs.strptime.array_strptime()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\_strptime.py:263, in TimeRE.compile(self, format)
#     262 """Return a compiled re object for the format string."""
# --> 263 return re_compile(self.pattern(format), IGNORECASE)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\_strptime.py:257, in TimeRE.pattern(self, format)
#     254 directive_index = format.index('%')+1
#     255 processed_format = "%s%s%s" % (processed_format,
# ...

# %%
# Group by date and count number of attacks per month

month_attacks = df_terrosism.groupby('date').size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-2.ipynb Cell 38 in 3
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X66sdW50aXRsZWQ%3D?line=0'>1</a> # Group by date and count number of attacks per month
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X66sdW50aXRsZWQ%3D?line=2'>3</a> month_attacks = df_terrosism.groupby('date').size()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:8389, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8386     raise TypeError("You have to supply one of 'by' and 'level'")
#    8387 axis = self._get_axis_number(axis)
# -> 8389 return DataFrameGroupBy(
#    8390     obj=self,
#    8391     keys=by,
#    8392     axis=axis,
# ...

# %%
# Line chart for the number of attacks per month

plt.plot(month_attacks.index, month_attacks.values)
plt.title('Number of attacks per month')
plt.xlabel('Date')
plt.ylabel('Number of attacks')
plt.show()

# %% [markdown]
# ## Type of most attacks

# %%
# Group by attack type and count the number of attacks for each type

type_attacks = df_terrosism.groupby('attacktype1_txt').size()

# %%
# Find which attack type has most attacks

most_type_attacks = type_attacks.idxmax()
print(f'The attack type with most attacks is {most_type_attacks}.')
# Out:
# The attack type with most attacks is Bombing/Explosion.

# %%
# Bar chart for number of attacks by type

plt.bar(type_attacks.index, type_attacks.values)
plt.title('Bar Chart for Number of Attacks by Type')
plt.xlabel('Attack Type')
plt.ylabel('Number of attacks')
plt.show()
